# %% [markdown]
# Number of bike stations for each year.
#
# In order to count the number of stations, we gathered all unique values from each years data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob

# %%
path =r'C:\Users\travi\Desktop\project-one-opm\trip_data\2011'

filenames = glob.glob(path + "/*.csv")

dfs = []

for filename in filenames:

    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame

data_2011 = pd.concat(dfs, ignore_index=True)
data_2011.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      3548  2011-01-01 00:01:29  2011-01-01 01:00:37                 31620
# 1       346  2011-01-01 00:02:46  2011-01-01 00:08:32                 31105
# 2       562  2011-01-01 00:06:13  2011-01-01 00:15:36                 31400
# 3       434  2011-01-01 00:09:21  2011-01-01 00:16:36                 31111
# 4       233  2011-01-01 00:28:26  2011-01-01 00:32:19                 31104
#
#                     Start station  End station number  \
# 0                   5th & F St NW               31620
# 1            14th & Harvard St NW               31101
# 2  Georgia & New Hampshire Ave NW               31104
# 3                  10th & U St NW               31503
# 4     Adams Mill & Columbia Rd NW               31106
#
#                    End station Bike number Member type
# 0                5th & F St NW      W00247      Member
# 1               14th & V St NW      W00675      Casual
# ...

# %%
path =r'C:\Users\travi\Desktop\project-one-opm\trip_data\2012'

filenames = glob.glob(path + "/*.csv")

dfs = []

for filename in filenames:

    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame

data_2012 = pd.concat(dfs, ignore_index=True)
data_2012.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       475  2012-01-01 00:04:00  2012-01-01 00:11:56                 31245
# 1      1162  2012-01-01 00:10:05  2012-01-01 00:29:28                 31400
# 2      1145  2012-01-01 00:10:23  2012-01-01 00:29:28                 31400
# 3       485  2012-01-01 00:15:41  2012-01-01 00:23:46                 31101
# 4       471  2012-01-01 00:15:42  2012-01-01 00:23:34                 31102
#
#                     Start station  End station number  \
# 0    7th & R St NW / Shaw Library               31109
# 1  Georgia & New Hampshire Ave NW               31103
# 2  Georgia & New Hampshire Ave NW               31103
# 3                  14th & V St NW               31602
# 4             11th & Kenyon St NW               31109
#
#                End station Bike number Member type
# 0            7th & T St NW      W01412      Member
# 1     16th & Harvard St NW      W00524      Casual
# ...

# %%
path =r'C:\Users\travi\Desktop\project-one-opm\trip_data\2013'

filenames = glob.glob(path + "/*.csv")

dfs = []

for filename in filenames:

    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame

data_2013 = pd.concat(dfs, ignore_index=True)
data_2013.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       688  2013-01-01 00:03:55  2013-01-01 00:15:24                 31101
# 1       699  2013-01-01 00:04:39  2013-01-01 00:16:19                 31236
# 2       365  2013-01-01 00:10:01  2013-01-01 00:16:06                 31257
# 3       292  2013-01-01 00:12:55  2013-01-01 00:17:47                 31614
# 4       222  2013-01-01 00:13:24  2013-01-01 00:17:07                 31239
#
#                             Start station  End station number  \
# 0                          14th & V St NW               31106
# 1  37th & O St NW / Georgetown University               31304
# 2           22nd & I St NW / Foggy Bottom               31239
# 3                          11th & H St NE               31612
# 4       Rhode Island & Connecticut Ave NW               31214
#
#                           End station Bike number Member type
# 0            Calvert & Biltmore St NW      W01210      Member
# ...

# %%
path =r'C:\Users\travi\Desktop\project-one-opm\trip_data\2014'

filenames = glob.glob(path + "/*.csv")

dfs = []

for filename in filenames:

    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame

data_2014 = pd.concat(dfs, ignore_index=True)
data_2014.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0      1716  2014-01-01 00:06:03  2014-01-01 00:34:40                 31102
# 1       154  2014-01-01 00:11:09  2014-01-01 00:13:43                 31602
# 2       318  2014-01-01 00:12:19  2014-01-01 00:17:38                 31223
# 3       480  2014-01-01 00:14:02  2014-01-01 00:22:02                 31203
# 4       345  2014-01-01 00:15:33  2014-01-01 00:21:18                 31241
#
#                        Start station  End station number  \
# 0                11th & Kenyon St NW               31632
# 1            Park Rd & Holmead Pl NW               31107
# 2  Convention Center / 7th & M St NW               31509
# 3         14th & Rhode Island Ave NW               31109
# 4                      Thomas Circle               31600
#
#                 End station Bike number Member type
# 0            15th & F St NE      W01363      Member
# 1   Lamont & Mt Pleasant NW      W01433      Member
# ...

# %%
path =r'C:\Users\travi\Desktop\project-one-opm\trip_data\
# 4       4th & East Capitol St NE               31619
#
#                                  End station Bike number Member type
# 0             Georgia & New Hampshire Ave NW      W00886      Member
# ...

# %%
# get data file names

path =r'C:\Users\travi\Desktop\project-one-opm\trip_data\2019'

filenames = glob.glob(path + "/*.csv")

dfs = []

for filename in filenames:

    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame

data_2019 = pd.concat(dfs, ignore_index=True)
data_2019.head()
# Out:
#    Duration           Start date             End date  Start station number  \
# 0       230  2019-01-01 00:04:48  2019-01-01 00:08:39                 31203
# 1      1549  2019-01-01 00:06:37  2019-01-01 00:32:27                 31321
# 2       177  2019-01-01 00:08:46  2019-01-01 00:11:44                 31104
# 3       228  2019-01-01 00:08:47  2019-01-01 00:12:35                 31281
# 4      1300  2019-01-01 00:12:29  2019-01-01 00:34:10                 31014
#
#                    Start station  End station number  \
# 0     14th & Rhode Island Ave NW               31200
# 1  15th St & Constitution Ave NW               31114
# 2    Adams Mill & Columbia Rd NW               31323
# 3                  8th & O St NW               31280
# 4           Lynn & 19th St North               31923
#
#                                          End station Bike number Member type
# 0               Massachusetts Ave & Dupont Circle NW      E00141      Member
# ...

# %%
stations = []

# %%
station_number = data_2011['Start station number']
station_address = data_2011['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2011_unique = bike_trip_location.drop_duplicates()
len(data_2011_unique.index)
stations.append(len(data_2011_unique.index))

# %%
station_number = data_2012['Start station number']
station_address = data_2012['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2012_unique = bike_trip_location.drop_duplicates()
len(data_2012_unique.index)
stations.append(len(data_2012_unique.index))

# %%
station_number = data_2013['Start station number']
station_address = data_2013['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2013_unique = bike_trip_location.drop_duplicates()
len(data_2013_unique.index)
stations.append(len(data_2013_unique.index))

# %%
station_number = data_2014['Start station number']
station_address = data_2014['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2014_unique = bike_trip_location.drop_duplicates()
len(data_2014_unique.index)
stations.append(len(data_2014_unique.index))

# %%
station_number = data_2015['Start station number']
station_address = data_2015['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2015_unique = bike_trip_location.drop_duplicates()
len(data_2015_unique.index)
stations.append(len(data_2015_unique.index))

# %%
station_number = data_2016['Start station number']
station_address = data_2016['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2016_unique = bike_trip_location.drop_duplicates()
len(data_2016_unique)
stations.append(len(data_2016_unique.index))

# %%
station_number = data_2017['Start station number']
station_address = data_2017['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2017_unique = bike_trip_location.drop_duplicates()
len(data_2017_unique)
stations.append(len(data_2017_unique.index))

# %%
station_number = data_2018['Start station number']
station_address = data_2018['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2018_unique = bike_trip_location.drop_duplicates()
len(data_2018_unique)
stations.append(len(data_2018_unique.index))

# %%
station_number = data_2019['Start station number']
station_address = data_2019['Start station']

bike_trip_location = pd.DataFrame(station_number)


#len(bike_trip_location['Start station number'].unique())
#bike_trip_location.head()
data_2019_unique = bike_trip_location.drop_duplicates()
len(data_2019_unique)
stations.append(len(data_2019_unique.index))

# %%
years=['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
years
# Out:
# ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
stations
# Out:
# [144, 191, 305, 346, 357, 435, 487, 528, 582]

# %%
plt.bar(years, stations, color='blue', alpha=0.8, align="center")
plt.title("Growth of Number of Bikeshare Locations")
plt.xlabel("Years")
plt.ylabel("Number of Stations")
# Out:
# Text(0, 0.5, 'Number of Stations')
